# %%
import _init_paths
import dataset
from config import cfg
from config import update_config

import matplotlib.pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
cfg.defrost()
cfg.merge_from_file("../experiments/salicon/w32_512x384_adam_lr1e-3.yaml")
cfg.freeze()

# %%
train_dataset = dataset.salicon(
    cfg, '../data/salicon/', cfg.DATASET.TRAIN_SET, True,
)

# %%
img, smap, _ = train_dataset.__getitem__(0)
# plt.imshow(img.transpose((1,2,0)))
plt.imshow(img)
plt.figure()
plt.imshow(smap)
